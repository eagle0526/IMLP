# %%
#載入資料
from sklearn.datasets import load_iris
import sklearn.datasets as datasets
import pandas as pd
from sklearn.model_selection import train_test_split

iris = datasets.load_iris()
print(iris["feature_names"])

x = pd.DataFrame(iris["data"], columns=iris["feature_names"])
x = x[["sepal length (cm)", "petal length (cm)"]]
x

print("target_name : " + str(iris["target_names"]))
Y = pd.DataFrame(iris["target"], columns=["target"])
Y

x_train, X_test, y_train, y_test = train_test_split(
    x,
    Y,
    test_size=0.3
    

)
x_train
y_train
X_test
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# target_name : ['setosa' 'versicolor' 'virginica']
#      sepal length (cm)  petal length (cm)
# 0                  5.1                1.4
# 83                 6.0                5.1
# 7                  5.0                1.5
# 1                  4.9                1.4
# 132                6.4                5.6
# 115                6.4                5.3
# 37                 4.9                1.4
# 54                 6.5                4.6
# 34                 4.9                1.5
# 49                 5.0                1.4
# 138                6.0                4.8
# 104                6.5                5.8
# 96                 5.7                4.2
# 18                 5.7                1.7
# 103                6.3                5.6
# 21                 5.1                1.5
# 105                7.6                6.6
# 106                4.9                4.5
# 136                6.3                5.6
# 124                6.7                5.7
# 66                 5.6                4.5
# 22                 4.6                1.0
# 126                6.2                4.8
# 77                 6.7                5.0
# 19                 5.1                1.5
# 102                7.1                5.9
# 95                 5.7                4.2
# 107                7.3                6.3
# 71                 6.1                4.0
# 123                6.3                4.9
# 92                 5.8                4.0
# 98                 5.1                3.0
# 75                 6.6                4.4
# 109                7.2                6.1
# 27                 5.2                1.5
# 112                6.8                5.5
# 113                5.7                5.0
# 68                 6.2                4.5
# 65                 6.7                4.4
# 80                 5.5                3.8
# 118                7.7                6.9
# 25                 5.0                1.6
# 33                 5.5                1.4
# 56                 6.3                4.7
# 52                 6.9                4.9

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np
from keras.utils import np_utils
#這個可以直接轉換

encoder = LabelEncoder()
encoded_Y = encoder.fit_transform(Y)
encoded_Y

#轉換one hot encoding
dummy_Y = np_utils.to_categorial(encoded_Y)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\EAGLE0~1\AppData\Local\Temp/ipykernel_10420/3421793857.py in <module>
#       1 from sklearn.preprocessing import LabelEncoder
#       2 import numpy as np
# ----> 3 from keras.utils import np_utils
#       4 #這個可以直接轉換
#       5
#
# ModuleNotFoundError: No module named 'keras'

# %%
#Z score優化

import numpy
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

sc = StandardScaler().fit(x_train)
sc.mean_   #mean
sc.scale_  #standard deviation

#transform: (x-u)/std.
s_train_std = sc.transform(x_train)
s_train_std

sc = StandardScaler().fit(X_test)

x_test_std = sc.transform(X_test)
x_test_std
# Out:
# array([[-1.08699657, -1.4590791 ],
#        [ 0.03319074,  0.63520254],
#        [-1.21146183, -1.40247689],
#        [-1.33592709, -1.4590791 ],
#        [ 0.53105176,  0.91821357],
#        [ 0.53105176,  0.74840695],
#        [-1.33592709, -1.4590791 ],
#        [ 0.65551702,  0.35219151],
#        [-1.33592709, -1.40247689],
#        [-1.21146183, -1.4590791 ],
#        [ 0.03319074,  0.46539592],
#        [ 0.65551702,  1.03141798],
#        [-0.34020503,  0.12578268],
#        [-0.34020503, -1.28927248],
#        [ 0.40658651,  0.91821357],
#        [-1.08699657, -1.40247689],
#        [ 2.02463484,  1.48423563],
#        [-1.33592709,  0.2955893 ],
#        [ 0.40658651,  0.91821357],
#        [ 0.90444753,  0.97481578],
#        [-0.46467029,  0.2955893 ],
#        [-1.70932286, -1.68548792],
#        [ 0.28212125,  0.46539592],
#        [ 0.90444753,  0.57860033],
#        [-1.08699657, -1.40247689],
#        [ 1.40230856,  1.08802019],
#        [-0.34020503,  0.12578268],
#        [ 1.65123907,  1.31442901],
#        [ 0.15765599,  0.01257827],
#        [ 0.40658651,  0.52199813],
#        [-0.21573978,  0.01257827],
#        [-1.08699657, -0.5534438 ],
#        [ 0.77998227,  0.23898709],
#        [ 1.52677381,  1.2012246 ],
#        [-0.96253132, -1.40247689],
#        [ 1.02891279,  0.86161136],
#        [-0.34020503,  0.57860033],
#        [ 0.28212125,  0.2955893 ],
#        [ 0.90444753,  0.23898709],
#        [-0.58913555, -0.10062614],
#        [ 2.1491001 ,  1.65404225],
#        [-1.21146183, -1.34587468],
#        [-0.58913555, -1.4590791 ],
#        [ 0.40658651,  0.40879371],
#        [ 1.15337804,  0.52199813]])
